# %% [markdown]
# <a href="https://colab.research.google.com/github/jackapolinarisa-25/StrukturData/blob/main/PRAKTIKUM%201%20DAN%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PRAKTIKUM 1

# %%
arr = []

# input 10 angka
for i in range(10):
    angka = int(input("Masukkan angka: "))
    arr.append(angka)

print("Array:", arr)
print("Nilai maksimum:", max(arr))
print("Nilai minimum:", min(arr))
print("Rata-rata:", sum(arr)/len(arr))
# Out:
# Masukkan angka: 2
# Masukkan angka: 3
# Masukkan angka: 5
# Masukkan angka: 7
# Masukkan angka: 79
# Masukkan angka: 45
# Masukkan angka: 23
# Masukkan angka: 4
# Masukkan angka: 1
# Masukkan angka: 23
# Array: [2, 3, 5, 7, 79, 45, 23, 4, 1, 23]
# Nilai maksimum: 79
# Nilai minimum: 1
# Rata-rata: 19.2

# %% [markdown]
# PRAKTIKUM 2

# %%
#buat grafik batang menggunakan matplotlib
import matplotlib.pyplot as plt
plt.bar(range(len(arr)), arr)
plt.title("Grafik Array")
plt.xlabel("Indeks")
plt.ylabel("Nilai")
plt.show()
